# %%
from sklearn.model_selection import train_test_split
import pandas as pd
from catboost import CatBoostRegressor, Pool
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('data.csv')
data.sample(n=10)
# Out:
#        wallsMaterial  floorNumber  floorsTotal  totalArea  kitchenArea  \
# 18884       monolith            3         14.0       35.1         11.2
# 47066          panel            6          9.0       32.5          6.7
# 44034          panel            1         12.0       35.0         10.0
# 29130       monolith           15         17.0       50.0         10.1
# 43386          brick            2          5.0       92.0          8.0
# 30095  monolithBrick            1          3.0       36.0         11.0
# 20968  monolithBrick           10         18.0      125.0         10.0
# 22384          panel            4          9.0       63.0          6.5
# 38439       monolith            2         18.0       41.0         12.2
# 56280          panel            9          9.0       73.0          8.5
#
#         latitude  longitude     price  priceMetr  distance  azimuth
# 18884  55.699954  37.637120   8240000   234758.0    5972.0    167.0
# ...

# %% [markdown]
# # Разделяем данные и создаем модель

# %%
y = data['priceMetr']
features = [
            'wallsMaterial', 
            'floorNumber', 
            'floorsTotal', 
            'totalArea', 
            'kitchenArea',
            'distance',
            'azimuth'
           ]
categorical_features = ['wallsMaterial']
X = data[features]
train_X, test_X, train_y, test_y = train_test_split(X, y, random_state=1)

train_pool = Pool(train_X, 
                  train_y, 
                  cat_features=categorical_features)
test_pool = Pool(test_X, 
                 cat_features=categorical_features)

# %%
model = CatBoostRegressor(iterations=1500, 
                          depth=2, 
                          learning_rate=1, 
                          loss_function='RMSE')

# %%
model.fit(train_pool)
# Out:
# 0:	learn: 92051.7032768	total: 57.1ms	remaining: 1m 25s
# 1:	learn: 85546.6259613	total: 61.6ms	remaining: 46.1s
# 2:	learn: 83340.8207049	total: 70.3ms	remaining: 35.1s
# 3:	learn: 81762.1021239	total: 76.4ms	remaining: 28.6s
# 4:	learn: 79640.8263484	total: 82.3ms	remaining: 24.6s
# 5:	learn: 78472.5125094	total: 87.4ms	remaining: 21.8s
# 6:	learn: 77639.0728480	total: 92ms	remaining: 19.6s
# 7:	learn: 75849.7158065	total: 97.2ms	remaining: 18.1s
# 8:	learn: 74694.2870765	total: 101ms	remaining: 16.7s
# 9:	learn: 74187.9671800	total: 105ms	remaining: 15.7s
# 10:	learn: 73932.9469275	total: 109ms	remaining: 14.7s
# 11:	learn: 73587.0172641	total: 113ms	remaining: 13.9s
# 12:	learn: 72988.5640291	total: 116ms	remaining: 13.3s
# 13:	learn: 72649.5614473	total: 120ms	remaining: 12.7s
# 14:	learn: 72165.9727223	total: 123ms	remaining: 12.2s
# 15:	learn: 71765.6043330	total: 126ms	remaining: 11.7s
# 16:	learn: 71311.4035008	total: 130ms	remaining: 11.3s
# ...

# %%
preds = model.predict(test_pool)
print(((preds - test_y) / test_y * 100).mean())
# Out:
# 12.572716993346008

# %%
from math import sqrt
print(sqrt(mean_squared_error(test_y, preds)))
# Out:
# 58910.77906837711

# %%
min(data['price'])
# Out:
# 750000
